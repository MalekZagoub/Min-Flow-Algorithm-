# %%
import random
import networkx as nx
import matplotlib.pyplot as plt


# Définir les paramètres du graphe
N = 20 # nombres des noeuds
A = 50 # nombres des arcs
C = 10 # coût unitaire d'un arc
U = 20 # la capacité maximale d'un arc


# Créer un graphe orienté aléatoire
G= nx.gnm_random_graph(20, 50, seed=11155441, directed=True)

for (u, v) in G.edges():
    G.edges[u, v]['capacité'] = random.randint(0, U)
    G.edges[u, v]['coût'] = random.randint(0, C)

# Afficher le graphe
print('Voici le graph obtenu dans une liste : ')
print(G.edges(data=True))

# Afficher le graphe
print('Voici le graph obtenu : ')
plt.subplots(figsize=(17,8))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, pos, with_labels=True, node_size=500, node_color='lightgreen', font_size=12, font_weight='bold')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels, font_size=10, font_weight='bold')
plt.show()
# Out:
# Voici le graph obtenu dans une liste :
# [(0, 16, {'capacité': 16, 'coût': 4}), (0, 17, {'capacité': 8, 'coût': 0}), (0, 5, {'capacité': 12, 'coût': 5}), (1, 11, {'capacité': 2, 'coût': 9}), (2, 9, {'capacité': 16, 'coût': 9}), (2, 17, {'capacité': 5, 'coût': 10}), (2, 7, {'capacité': 14, 'coût': 10}), (3, 19, {'capacité': 2, 'coût': 6}), (3, 8, {'capacité': 7, 'coût': 1}), (3, 0, {'capacité': 17, 'coût': 2}), (4, 10, {'capacité': 6, 'coût': 5}), (4, 19, {'capacité': 2, 'coût': 5}), (5, 18, {'capacité': 17, 'coût': 9}), (6, 7, {'capacité': 5, 'coût': 4}), (6, 2, {'capacité': 1, 'coût': 2}), (6, 3, {'capacité': 5, 'coût': 8}), (7, 4, {'capacité': 17, 'coût': 9}), (7, 8, {'capacité': 20, 'coût': 0}), (8, 17, {'capacité': 0, 'coût': 9}), (8, 4, {'capacité': 2, 'coût': 5}), (8, 18, {'capacité': 18, 'coût': 8}), (8, 2, {'capacité': 3, 'coût': 2}), (8, 14, {'capacité': 1, 'coût': 9}), (9, 18, {'capacité': 20, 'coût': 0}), (9, 11, {'capacité': 14, 'coût': 0}), (10, 0, {'capacité': 5, 'coût': 6}), (10, 2, {'capacité': 8, 'coût': 2}), (10, 19, {'capacité': 14, 'coût': 7}), (10, 4, {'capacité': 2, 'coût': 0}), (11, 14, {'capacité': 15, 'coût': 9}), (11, 16, {'capacité': 6, 'coût': 5}), (11, 4, {'capacité': 3, 'coût': 8}), (12, 13, {'capacité': 11, 'coût': 10}), (12, 5, {'capacité': 14, 'coût': 9}), (12, 7, {'capacité': 0, 'coût': 9}), (13, 12, {'capacité': 1, 'coût': 4}), (14, 2, {'capacité': 11, 'coût': 3}), (14, 6, {'capacité': 18, 'coût': 10}), (14, 17, {'capacité': 11, 'coût': 3}), (15, 17, {'capacité': 14, 'coût': 1}), (15, 9, {'capacité': 3, 'coût': 8}), (15, 1, {'capacité': 14, 'coût': 2}), (16, 8, {'capacité': 7, 'coût': 2}), (16, 4, {'capacité': 0, 'coût': 6}), (16, 15, {'capacité': 18, 'coût': 9}), (17, 18, {'capacité': 18, 'coût': 5}), (18, 5, {'capacité': 14, 'coût': 1}), (18, 16, {'capacité': 16, 'coût': 0}), (19, 8, {'capacité': 8, 'coût': 5}), (19, 7, {'capacité': 3, 'coût': 4})]
# Voici le graph obtenu :
